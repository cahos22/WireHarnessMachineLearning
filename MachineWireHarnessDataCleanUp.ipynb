# %%
import pandas as pd
import numpy as np

# %%
sample_data = pd.read_csv('Resources/Data/46_May.csv')
sample_data = sample_data.dropna(how="any")

# %%
sample_data.head()
# Out:
#     Index         Date  Unknown  \
# 2       3  1/5/18 0:04        1
# 28     29  1/5/18 1:37        1
# 29     30  1/5/18 1:37        1
# 30     31  1/5/18 1:37        1
# 42     43  1/5/18 1:37        1
#
#                                               Message  Code  Parameter_from  \
# 2   Work Data Change: Wire Length is from 1255 to ...   257          1255.0
# 28  Work Data Change: Wire Feed Speed 1 is from 4....  2564             4.0
# 29  Work Data Change: Wire Feed Speed 2 is from 4....  2565             4.0
# 30  Work Data Change: Wire Length Correction 2 is ...  2562             0.0
# 42  Work Data Change: Wire Length is from 1705 to ...   257          1705.0
#
#     Parameter_to
# 2         1705.0
# 28           3.0
# 29          10.0
# 30           1.7
# 42        1675.0

# %%
# function to extract only cities from location column
def split_record(info):
    ret_val = info.split(":")[1]
    return ret_val

# %%
sample_data[['3','message']] = sample_data['3'].str.split(':',expand=True)
sample_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/pythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-aac27b26a93a> in <module>()
# ----> 1 sample_data[['3','message']] = sample_data['3'].str.split(':',expand=True)
#       2 sample_data
#
# ~/anaconda3/envs/pythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/envs/pythonData/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/pythonData/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/envs/pythonData/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/pythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '3'

# %%
sample_data["Description"] = sample_data[3].map(split_record)

# %%
sample_data.head()
# Out:
#      0                    1  2  \
# 16  16  30/05/2018 10:42:05  1
# 17  17  30/05/2018 10:42:05  1
# 18  18  30/05/2018 10:42:05  1
# 33  33  30/05/2018 10:42:05  1
# 34  34  30/05/2018 10:42:05  1
#
#                                                     3     4      5      6  \
# 16  Work Data Change: Wire Length Correction 1 is ...  2561    0.0    1.7
# 17  Work Data Change: Wire Length Correction 2 is ...  2562    1.7    0.0
# 18  Work Data Change: Wire Length Correction 3 is ...  2563    0.7    0.0
# 33   Work Data Change: Wire Length is from 440 to 100   257  440.0  100.0
# 34  Work Data Change: Strip Length 1 is from 3.7 t...   513    3.7    0.0
#
#                                      Description
# 16   Wire Length Correction 1 is from 0.0 to 1.7
# 17   Wire Length Correction 2 is from 1.7 to 0.0
# 18   Wire Length Correction 3 is from 0.7 to 0.0
# 33                Wire Length is from 440 to 100
# 34             Strip Length 1 is from 3.7 to 0.0
